# %% [markdown]
# <a href="https://colab.research.google.com/github/niapermatasari1606-lab/kka-semester-1/blob/main/2_Tipe_Variabel_Nia_Permata_Sari_Xl_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Nia Permata Sari
# Kelas: Xl-1
# No.absen: 29

# %% [markdown]
# Konsep Dasar

# %%
email_user_1 = "niapermatasari1606@gmail.com"

print(email_user_1)
# Out:
# niapermatasari1606@gmail.com

# %%
sabun_lifebuoy = 15000

print(sabun_lifebuoy)
# Out:
# 15000

# %% [markdown]
# Peraturan Penulisan Variabel

# %%
#Penulisan variabel hanya boleh menggunakan huruf, angka dan underscore
#Tidak boleh menggunakan spasi
nama siswa = "Niacomel"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-255417849.py", line 3
#     nama siswa = "Niacomel"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka

1_nama_siswa = "Niacomel"

print(Nama_siswa_1)
# Out:
#   File "/tmp/ipython-input-1738201306.py", line 3
#     1_nama_siswa = "Niacomel"
#      ^
# SyntaxError: invalid decimal literal

# %%
# penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "Niacan"
print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2753252964.py in <cell line: 0>()
#       1 # penulisan variabel itu case sensitive/sensitif capslock
#       2 nama_siswa_1 = "Niacan"
# ----> 3 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#Dilarang mengunakan kata kunci di Bahasa Python
prin = "Niacomel"

print(prin)
# Out:
# Niacomel

# %%
end = "Niaimut"

print(end)
# Out:
# Niaimut

# %%
#Deskriptif
_ = "Niacantik"

print(_)
# Out:
# Niacantik

# %%
# Tidak boleh pakai kata kunci python
# Kalau error, harus disconnect dulu
# print = "Nialucu"

# print(print)

# %% [markdown]
# Assignment

# %% [markdown]
# Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Selo"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Selo

# %% [markdown]
# Assign ke Banyak Variabel Sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# Aritmarika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#Simpan operand ke dalam variabel
harga_kojek = 6000
banyak_porsi = 3

print(harga_kojek*banyak_porsi)
# Out:
# 18000

# %%
#Simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#Simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = 100000
uang_kembalian = uang_yang_diterima - harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65
type(usia)
# Out:
# int

# %%
berat_telur = 2.5
type(berat_telur)
# Out:
# float

# %%
nama = "Nia"
type(nama)
# Out:
# str

# %%
remidi = False
type(remidi)
# Out:
# bool

# %%
remidi = True
type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5
type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type(koordinat_titik)
# Out:
# int

# %% [markdown]
# input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang = input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
luas = panjang*lebar
print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1308584410.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input(" Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2
print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 5
#  Masukkan lebar persegi: 2
# Luas persegi panjang adalah 10 cm^2

# %% [markdown]
# #Latihan soal

# %%
panjang_1 = int(input("Masukkan panjang: "))
lebar_1 = int(input(" Masukkan lebar: "))
tinggi_1 = int(input(" Masukkan tinggi: "))

volume_1 = panjang_1*lebar_1*tinggi_1
print(f"Volume balok tersebut adalah {volume_1} cm^3")
# Out:
# Masukkan panjang: 10
#  Masukkan lebar: 5
#  Masukkan tinggi: 4
# Volume balok tersebut adalah 200 cm^3

# %% [markdown]
# Konversi tipe data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print (a)
type (a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-192500151.py in <cell line: 0>()
# ----> 1 a = bool(a)
#       2 print (a)
#       3 type (a)
#
# NameError: name 'a' is not defined

# %%
b = "cicak"
print(b)

b = bool (b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool (c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %% [markdown]
# Operator Perbandingan

# %%
print(8<5)
# Out:
# False

# %%
print(8>5)
# Out:
# True

# %%
print(9>=9)
# Out:
# True

# %%
print(8 == 5)
# Out:
# False

# %%
print(1 !=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a>b)
# Out:
# False

# %%
print(a>30)
# Out:
# False

# %%
nilai_kka = 75
kkm_kka = 80

print(nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# Operator Logika

# %%
print(8>7 and 5>6)
# Out:
# False

# %%
print(8>7 and 5<6)
# Out:
# True

# %%
print(8>7 or 5>6)
# Out:
# True

# %%
print(not(8>7 or 5>6))
# Out:
# False

# %%
print(not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print(125 >= iq_min and 170>= tinggi_min)
# Out:
# True

# %%
iq_afa = 125
tinggi_afa = 170

print(iq_afa >= iq and tinggi_afa >= tinggi_min)
# Out:
#   File "/tmp/ipython-input-424706942.py", line 4
#     print(iq_afa >= and tinggi_afa >= tinggi_min)
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Tugas membuat program volume kerucut

# %% [markdown]
# Nama : nia permata sari
# Kelas : Xl-1
# No absen : 29
# Nama kelompok : perfect

# %% [markdown]
# #Aplikadi sederhana menghitung volume kerucut

# %%
qjari_jari = float(input("masukkan jari jari kerucut: "))
tinggi = float(input("masukkan tinggi kerucut: "))
pi = 3.14

volume = (1/3) * pi * (jari_jari**2) * tinggi
print(f" volume kerucut adalah {volume} cm^3")
# Out:
# masukkan jari jari kerucut: 7
# masukkan tinggi kerucut: 10
#  volume kerucut adalah 512.8666666666666 cm^3
