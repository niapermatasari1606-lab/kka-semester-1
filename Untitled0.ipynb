# %% [markdown]
# <a href="https://colab.research.google.com/github/niapermatasari1606-lab/kka-semester-1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Menampilkan Teks Bebas

# %%
print("halo dunia ")
# Out:
# halo dunia

# %%
print('selamat datang di python')
# Out:
# selamat datang di python

# %%
print('nia permata sari')
# Out:
# nia permata sari

# %% [markdown]
# # variabel

# %%
BB = 50
print(BB)
# Out:
# 50

# %%
UMUR = 15
print(15)
# Out:
# 15

# %%
NAMA = "nia permata sari"
print(NAMA)
# Out:
# nia permata sari

# %% [markdown]
# # Menampilkan teks bebas dan variabel

# %%
print(f"umur saya{UMUR}tahun")
# Out:
# umur saya15tahun

# %%
print("Halo" + nama)
# Out:
# Halonia permata sari

# %%
harga_telur = 26000
print("Harga telur per 1 kg adalah ", harga_telur)
# Out:
# Harga telur per 1 kg adalah  26000

# %%
nama_pembeli = "Ilham"
print("Nama pembeli telur adalah " + nama_pembeli)
# Out:
# Nama pembeli telur adalah Ilham

# %% [markdown]
# Latihan soal
# 1. Tampilkan teks bebas: Hati ini saya bahagia belajar bahasa Python
# 2. Tampilan nilai variabel: mata_pelajaran_favorit = Kode dan Kecerdasan Buatan
# 3. Tampilkan nilai variabel: nilai_kka = 100
# 4. Tampilkan teks bebas dan nilai variabel dengan tiga metode (f string, "+", ","):" Nilai KKA saya adalah {nilai_kka} loh!"

# %% [markdown]
# #Escape Character

# %%
print("Nama: Nia Permata Sari")
print("Kelas: XI.1")
print("Nomor absen: 29")
# Out:
# Nama: Nia Permata Sari
# Kelas: XI.1
# Nomor absen: 29

# %%
print("Nama: Nia Permata Sari\nKelas: XI.1\nNomor absen: 29")
# Out:
# Nama: Nia Permata Sari
# Kelas: XI.1
# Nomor absen: 29

# %%
print("""Nama: Nia Permata Sari
Kelas: Xl.1
Nomor absen: 29""")
# Out:
# Nama: Nia Permata Sari
# Kelas: Xl.1
# Nomor absen: 29

# %%
print("Nama\t\t: Nia Permata Sari\nKelas\t\t: XI.1\nNomor absen\t: 29")
# Out:
# Nama		: Nia Permata Sari
# Kelas		: XI.1
# Nomor absen	: 29

# %%
print ('Ja\'far Shodiq')
# Out:
# Ja'far Shodiq

# %%
print ("Ja'far Shodiq")
# Out:
# Ja'far Shodiq

# %%
print ("Bu Shinta berkata, \"semua harus menyimak pelajaran. \"")
# Out:
# Bu Shinta berkata, "semua harus menyimak pelajaran. "

# %%
print('Bu Shinta berkata, "semua harus menyimak pelajaran."')
# Out:
# Bu Shinta berkata, "semua harus menyimak pelajaran."

# %%
print("lokasi file vidio karnaval ada di D:\\Karnaval 2025\\mp4")
# Out:
# lokasi file vidio karnaval ada di D:\Karnaval 2025\mp4

# %%
Tahun = 2010
Bulan = "Juni"
Tanggal = 16

print(Tanggal, end=" ")
print(Bulan, end=" ")
print(Tahun)
# Out:
# 16 Juni 2010

# %%
Tahun = 2010
Bulan = "Juni"
Tanggal =16

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 16/Juni/2010

# %% [markdown]
# Latihan:
# Tanggal-Bulan-Tahun

# %%
Nama_depan = "Nia"
Nama_belakang = "imut"

print(Nama_depan, Nama_belakang)
# Out:
# Nia imut

# %%
Nama_depan = "Nia"
Nama_belakang = "imut"

print(Nama_depan, end=" ")
print(Nama_belakang)
# Out:
# Nia imut

# %%
print("Bu Shinta berkata, \"berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing masing di folder local disk D:\\Jadwal Pelajaran\\Kelas Xl Semester l\" ")

print("\nJadwal Pelajaran Mingguan")

print("=====================================================")

print("jam\tSenin\t\tSelasa\t\tRabu")

print("jam 1\tMatematika\tBahasa\t\tImformatika")

print("jam 2\tBahasa Ing.\tSejarah\t\tMa'rifatullah")

print("jam 3\tInformatika\tOlahraga\tBiologi")
# Out:
# Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing masing di folder local disk D:\Jadwal Pelajaran\Kelas Xl Semester l"
#
# Jadwal Pelajaran Mingguan
# =====================================================
# jam	Senin		Selasa		Rabu
# jam 1	Matematika	Bahasa		Imformatika
# jam 2	Bahasa Ing.	Sejarah		Ma'rifatullah
# jam 3	Informatika	Olahraga	Biologi
